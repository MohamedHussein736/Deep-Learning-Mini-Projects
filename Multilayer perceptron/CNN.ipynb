# %%
from IPython.display import HTML

HTML('''
<script>code_show=true; 

function code_toggle() {
    if (code_show){
    $('div.input').hide();
    } else {
    $('div.input').show();
    }
    code_show = !code_show
} 

$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to show or hide your raw code."></form>
''')
# Out:
# <script>code_show=true;
#
# function code_toggle() {
#     if (code_show){
#     $('div.input').hide();
#     } else {
#     $('div.input').show();
#     }
#     code_show = !code_show
# }
#
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to show or hide your raw code."></form>

# %%
# Model 
input_size = 784
output_size = 10
hidden_layer_size = 150

model_sec = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='tanh'),
    tf.keras.layers.Dense(output_size,activation='softmax')
])

model_sec.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

NUM_EPOCHS = 8

history_exp_Sec = model_sec.fit(train_data,epochs=NUM_EPOCHS,validation_data=(validation_inputs,
validation_targets),verbose=1)

#Testing
test_loss,test_accuracy=model_sec.evaluate(test_data)

# %% [markdown]
# **Best obtained model using Dense modules is shown below**.
#
# [x] Testing VI.
#
# NN Architecture: Three ReLu functions
#
# hidden layer size : 2500
#
# BATCH size : 1000
#
# NUM_EPOCHS=8
#
# Acc training :0.9837
#
# Acc Testing : 0.9802

# %%
# Model 
input_size = 784
output_size = 10
hidden_layer_size = 2500

model_sec = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(output_size,activation='softmax')
])

model_sec.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

NUM_EPOCHS = 8

history_exp_Sec = model_sec.fit(train_data,epochs=NUM_EPOCHS,validation_data=(validation_inputs,
validation_targets),verbose=1)

# Plotting
print(history_exp_Sec.history.keys())
#  "Accuracy"
plt.plot(history_exp_Sec.history['accuracy'])
plt.plot(history_exp_Sec.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history_exp_Sec.history['loss'])
plt.plot(history_exp_Sec.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

#Testing
test_loss,test_accuracy=model_sec.evaluate(test_data)
# Out:
# Epoch 1/8
# 540/540 [==============================] - 11s 19ms/step - loss: 0.3423 - accuracy: 0.8938 - val_loss: 0.1397 - val_accuracy: 0.9588
# Epoch 2/8
# 540/540 [==============================] - 11s 19ms/step - loss: 0.1028 - accuracy: 0.9717 - val_loss: 0.1020 - val_accuracy: 0.9725
# Epoch 3/8
# 540/540 [==============================] - 11s 19ms/step - loss: 0.0667 - accuracy: 0.9803 - val_loss: 0.1127 - val_accuracy: 0.9717
# Epoch 4/8
# 540/540 [==============================] - 11s 19ms/step - loss: 0.0527 - accuracy: 0.9842 - val_loss: 0.1012 - val_accuracy: 0.9750
# Epoch 5/8
# 540/540 [==============================] - 11s 19ms/step - loss: 0.0481 - accuracy: 0.9859 - val_loss: 0.1074 - val_accuracy: 0.9745
# Epoch 6/8
# 540/540 [==============================] - 11s 19ms/step - loss: 0.0468 - accuracy: 0.9861 - val_loss: 0.0935 - val_accuracy: 0.9778
# Epoch 7/8
# ...

# %% [markdown]
# ## Model with customized compiler

# %%
# Model 
input_size = 784
output_size = 10
hidden_layer_size = 2500

model_custom = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(output_size,activation='softmax')
])

# Training

NUM_EPOCHS = 8

#model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# Since we want to have a customized optimizer, use:
custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
model_custom.compile(optimizer=custom_optimizer,loss='mean_squared_error',metrics=['accuracy'])

history_exp_cus = model_custom.fit(train_data,epochs=NUM_EPOCHS,validation_data=(validation_inputs, validation_targets),verbose=2)

#Testing
test_loss,test_accuracy=model_custom.evaluate(test_data)

# Plotting
print(history_exp_cus.history.keys())
#  "Accuracy"
plt.plot(history_exp_cus.history['accuracy'])
plt.plot(history_exp_cus.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history_exp_cus.history['loss'])
plt.plot(history_exp_cus.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/8
# 540/540 - 7s - loss: 27.2885 - accuracy: 0.0516 - val_loss: 27.4945 - val_accuracy: 0.0517
# Epoch 2/8
# 540/540 - 6s - loss: 27.2834 - accuracy: 0.0504 - val_loss: 27.4945 - val_accuracy: 0.0507
# Epoch 3/8
# 540/540 - 6s - loss: 27.2741 - accuracy: 0.0508 - val_loss: 27.4945 - val_accuracy: 0.0525
# Epoch 4/8
# 540/540 - 6s - loss: 27.2723 - accuracy: 0.0522 - val_loss: 27.4945 - val_accuracy: 0.0528
# Epoch 5/8
# 540/540 - 6s - loss: 27.2823 - accuracy: 0.0539 - val_loss: 27.4945 - val_accuracy: 0.0542
# Epoch 6/8
# 540/540 - 6s - loss: 27.2605 - accuracy: 0.0559 - val_loss: 27.4945 - val_accuracy: 0.0560
# Epoch 7/8
# 540/540 - 6s - loss: 27.2951 - accuracy: 0.0571 - val_loss: 27.4945 - val_accuracy: 0.0568
# Epoch 8/8
# 540/540 - 6s - loss: 27.2789 - accuracy: 0.0579 - val_loss: 27.4945 - val_accuracy: 0.0578
# 1/1 [==============================] - 1s 716ms/step - loss: 27.2504 - accuracy: 0.0597
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Convolutional Neural Network - Experiment 1

# %%
# Model experiment 2
input_size = 784
output_size = 10
hidden_layer_size = 127

model_CNN_exp_1 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3)),
    tf.keras.layers.Conv2D(64, (3, 3)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(100,activation='relu',kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(output_size,activation='softmax')
])

# Training

NUM_EPOCHS = 8

model_CNN_exp_1.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# Since we want to have a customized optimizer, use:
#custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
#model.compile(optimizer=custom_optimizer,loss='mean_squared_error',metrics=['accuracy'])

history_exp_1 = model_CNN_exp_1.fit(train_data,epochs=NUM_EPOCHS,validation_data=(validation_inputs, validation_targets),verbose=2)

#Testing
test_loss,test_accuracy=model_CNN_exp_1.evaluate(test_data)
# Plotting
print(history_exp_1.history.keys())
#  "Accuracy"
plt.plot(history_exp_1.history['accuracy'])
plt.plot(history_exp_1.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history_exp_1.history['loss'])
plt.plot(history_exp_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/8
# 540/540 - 6s - loss: 0.1869 - accuracy: 0.9446 - val_loss: 0.0825 - val_accuracy: 0.9748
# Epoch 2/8
# 540/540 - 5s - loss: 0.0596 - accuracy: 0.9824 - val_loss: 0.0757 - val_accuracy: 0.9785
# Epoch 3/8
# 540/540 - 5s - loss: 0.0425 - accuracy: 0.9872 - val_loss: 0.0553 - val_accuracy: 0.9840
# Epoch 4/8
# 540/540 - 5s - loss: 0.0325 - accuracy: 0.9898 - val_loss: 0.0535 - val_accuracy: 0.9858
# Epoch 5/8
# 540/540 - 5s - loss: 0.0268 - accuracy: 0.9917 - val_loss: 0.0536 - val_accuracy: 0.9868
# Epoch 6/8
# 540/540 - 5s - loss: 0.0216 - accuracy: 0.9927 - val_loss: 0.0523 - val_accuracy: 0.9863
# Epoch 7/8
# 540/540 - 5s - loss: 0.0184 - accuracy: 0.9940 - val_loss: 0.0632 - val_accuracy: 0.9848
# Epoch 8/8
# 540/540 - 5s - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0565 - val_accuracy: 0.9862
# 1/1 [==============================] - 1s 714ms/step - loss: 0.0497 - accuracy: 0.9875
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Convolutional Neural Network - Experiment 2

# %%
# Model  experiment 3
input_size = 784
output_size = 10
hidden_layer_size = 127

model_CNN_exp_2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(64, (3, 3),activation = 'relu',  input_shape=(28,28,1)),
    tf.keras.layers.Conv2D(64, (3, 3),activation = 'relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    
    tf.keras.layers.Conv2D(128, (3, 3),activation = 'relu'),
    tf.keras.layers.Conv2D(128, (3, 3),activation = 'relu'),
    
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    
    tf.keras.layers.Conv2D(256, (3, 3),activation = 'relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(512,activation='relu',kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(output_size,activation='softmax')
])

# Training

NUM_EPOCHS = 8

model_CNN_exp_2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# Since we want to have a customized optimizer, use:
#custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
#model.compile(optimizer=custom_optimizer,loss='mean_squared_error',metrics=['accuracy'])

history_exp_2 = model_CNN_exp_2.fit(train_data,epochs=NUM_EPOCHS,validation_data=(validation_inputs, validation_targets),verbose=2)

#Testing
test_loss,test_accuracy=model_CNN_exp_2.evaluate(test_data)

# Plotting
print(history_exp_2.history.keys())
#  "Accuracy"
plt.plot(history_exp_2.history['accuracy'])
plt.plot(history_exp_2.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history_exp_2.history['loss'])
plt.plot(history_exp_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/8
# 540/540 - 12s - loss: 0.1608 - accuracy: 0.9491 - val_loss: 0.0580 - val_accuracy: 0.9838
# Epoch 2/8
# 540/540 - 12s - loss: 0.0398 - accuracy: 0.9874 - val_loss: 0.0427 - val_accuracy: 0.9875
# Epoch 3/8
# 540/540 - 12s - loss: 0.0261 - accuracy: 0.9915 - val_loss: 0.0366 - val_accuracy: 0.9913
# Epoch 4/8
# 540/540 - 12s - loss: 0.0213 - accuracy: 0.9930 - val_loss: 0.0356 - val_accuracy: 0.9905
# Epoch 5/8
# 540/540 - 12s - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0333 - val_accuracy: 0.9925
# Epoch 6/8
# 540/540 - 12s - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.0312 - val_accuracy: 0.9930
# Epoch 7/8
# 540/540 - 12s - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0403 - val_accuracy: 0.9902
# Epoch 8/8
# 540/540 - 12s - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.0374 - val_accuracy: 0.9917
# 1/1 [==============================] - 1s 1s/step - loss: 0.0281 - accuracy: 0.9922
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Convolutional Neural Networks - Experiment 3

# %%
# Model experiment 3
input_size = 784
output_size = 10
hidden_layer_size = 127

model_CNN_exp_3 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(64, (5, 5),activation = 'relu',  input_shape=(28,28,1)),
    tf.keras.layers.Conv2D(64, (5, 5),activation = 'relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    
    tf.keras.layers.Conv2D(128, (3, 3),activation = 'relu'),
    tf.keras.layers.Conv2D(128, (3, 3),activation = 'relu'),
    
    tf.keras.layers.Conv2D(256, (3, 3),activation = 'relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(512,activation='relu',kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(output_size,activation='softmax')
])

# Training

NUM_EPOCHS = 8

model_CNN_exp_3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# Since we want to have a customized optimizer, use:
#custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
#model.compile(optimizer=custom_optimizer,loss='mean_squared_error',metrics=['accuracy'])

history_exp_3 = model_CNN_exp_3.fit(train_data,epochs=NUM_EPOCHS,validation_data=(validation_inputs, validation_targets),verbose=2)

#Testing
test_loss,test_accuracy= model_CNN_exp_3.evaluate(test_data)

print(history_exp_3.history.keys())
#  "Accuracy"
plt.plot(history_exp_3.history['accuracy'])
plt.plot(history_exp_3.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history_exp_3.history['loss'])
plt.plot(history_exp_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/8
# 540/540 - 12s - loss: 0.1596 - accuracy: 0.9481 - val_loss: 0.0586 - val_accuracy: 0.9843
# Epoch 2/8
# 540/540 - 11s - loss: 0.0444 - accuracy: 0.9865 - val_loss: 0.0484 - val_accuracy: 0.9855
# Epoch 3/8
# 540/540 - 11s - loss: 0.0339 - accuracy: 0.9896 - val_loss: 0.0401 - val_accuracy: 0.9878
# Epoch 4/8
# 540/540 - 11s - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.0342 - val_accuracy: 0.9915
# Epoch 5/8
# 540/540 - 11s - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.0261 - val_accuracy: 0.9930
# Epoch 6/8
# 540/540 - 11s - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.0314 - val_accuracy: 0.9903
# Epoch 7/8
# 540/540 - 11s - loss: 0.0158 - accuracy: 0.9951 - val_loss: 0.0388 - val_accuracy: 0.9905
# Epoch 8/8
# 540/540 - 11s - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0284 - val_accuracy: 0.9902
# 1/1 [==============================] - 2s 2s/step - loss: 0.0286 - accuracy: 0.9915
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Best CNN architectures

# %%
#  "Accuracy"

plt.plot(history_exp_1.history['accuracy'])
plt.plot(history_exp_2.history['accuracy'])
plt.plot(history_exp_3.history['accuracy'])

plt.title('CNN models accuracies')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Model 1', 'Model 2', 'Model 3'], loc='upper left')
plt.show()

#  "Validation - accuracy"

plt.plot(history_exp_1.history['val_accuracy'])
plt.plot(history_exp_2.history['val_accuracy'])
plt.plot(history_exp_3.history['val_accuracy'])

plt.title('CNN models val-accuracy')
plt.ylabel('val-accuracy')
plt.xlabel('epoch')
plt.legend(['Model 1', 'Model 2', 'Model 3'], loc='upper left')
plt.show()

#  "Loss"

plt.plot(history_exp_1.history['loss'])
plt.plot(history_exp_2.history['loss'])
plt.plot(history_exp_3.history['loss'])

plt.title('CNN models loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Model 1', 'Model 2', 'Model 3'], loc='upper left')
plt.show()

# %%
current_score = model_CNN_exp_3.predict_proba(validation_inputs)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %% [markdown]
# # Report
#
# ### 1. Try a hidden layer size of 200. How does the validation accuracy of the model change? What about the time it took the algorithm to train? Can you find a hidden layer size that does better?
#
# **Remarks** Using 200 layer size (width) yielded loss: 0.0788 - accuracy: 0.9790 and took 5 seconds.
#
# THe best result so far has been increasing the # hidden layers up to 2000 or around this number
#
# Other tested configurations are the following, demonstrating that setting VI obtained the best results.
#
# [x] Testing I. Time: 10 secs
#
# hidden layer size : 2000
#
# BATCH size : 1000
#
# NUM_EPOCHS=5
#
# Acc training : 0.9768
# Acc testing  : 0.9777
#
# [x] Testing II.
#
# hidden layer size : 150
#
# BATCH size : 1000
#
# NUM_EPOCHS=5
#
# Acc training : 0.9593
# Acc testing  : 0.9627
#
# [x] Testing III.
#
# hidden layer size : 100
#
# BATCH size : 1000
#
# NUM_EPOCHS=8
#
# Acc training : 0.9543
# Acc testing  : 0.9570
#
#
# [x] Testing IV.
#
# hidden layer size : 500
#
# BATCH size : 1000
#
# NUM_EPOCHS=8
#
# Acc training :0.9727
# Acc testing  : 0.9737
#
#
# [x] Testing V.
#
# NN Architecture: Three ReLu functions
#
# hidden layer size : 1500
#
# BATCH size : 1000
#
# NUM_EPOCHS=8
#
# Acc training :0.9800
# Acc testing  : 0.9789
#
# [x] Testing VI.
#
# NN Architecture: Three ReLu functions
#
# hidden layer size : 2500
#
# BATCH size : 1000
#
# NUM_EPOCHS=8
#
# Acc training :0.9837
#
# Acc Testing  : 0.9802
#
# [x] Testing VII.
#
# NN Architecture: Three ReLu functions
#
# hidden layer size : 100
#
# BATCH size : 1000
#
# NUM_EPOCHS = 8
#
# Acc training :0.9660
#
# Acc Testing  : 0.9681

# %% [markdown]
# ### 2. The *depth* of the algorithm. Add another hidden layer to the algorithm. This is an extremely important exercise! How does the validation accuracy change? What about the time it took the algorithm to train? Hint: Be careful with the shapes of the weights and the biases.
#
# Takes longer time, the larger the depth, the larger the processing time. Equivalently with when the width is increased.

# %% [markdown]
# ### 3. The *width and depth* of the algorithm. Add as many additional layers as you need to reach 5 hidden layers. Moreover, adjust the width of the algorithm as you find suitable. How does the validation accuracy change? What about the time it took the algorithm to train?
#
# Each epoch increased time processing by 1 second, yielding 5 to 6 seconds each. Since there are 5 layers, took around 30-36 seconds and the validation accuracy decreased to: 0.9739

# %% [markdown]
# ### 4. Fiddle with the activation functions. Try applying sigmoid transformation to both layers. The sigmoid activation is given by the string 'sigmoid'.
#
# The accuracy drops in with the following performance parameters:
#
# 54/54 - 3s - loss: 0.2148 - accuracy: 0.9374 - val_loss: 0.2175 - val_accuracy: 0.9370
#
#
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2108 - accuracy: 0.9371

# %% [markdown]
# ### 5. Fiddle with the activation functions. Try applying a ReLu to the first hidden layer and tanh to the second one. The tanh activation is given by the string 'tanh'.
#
# The accuracy increased in validation and testing:
#
# 540/540 [==============================] - 5s 9ms/step - loss: 0.0263 - accuracy: 0.9913 - val_loss: 0.0929 - val_accuracy: 0.9750
# 1/1 [==============================] - 1s 589ms/step - loss: 0.0844 - accuracy: 0.9773

# %% [markdown]
# ### 6. Adjust the batch size. Try a batch size of 10000. How does the required time change? What about the accuracy?
#
# **Remarks** The time processing is faster (4s per epoch), because the batch is bigger, the time processing is faster. Results depicted lower accuracy as shown below.
#
# 6/6 - 11s - loss: 1.2245 - accuracy: 0.6908 - val_loss: 1.0999 - val_accuracy: 0.7257
#
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0845 - accuracy: 0.7413

# %% [markdown]
# ### 7. Adjust the batch size. Try a batch size of 1. That's the SGD. How do the time and accuracy change? Is the result coherent with the theory?
#
# Time processing is extremely slow. This would be equivalent as training the model based on a one-by-one sample, from the traning set. Which would take much longer time.

# %% [markdown]
# ### 8. Adjust the learning rate. Try a value of 0.0001. Does it make a difference?
#
# The results drop, as shown below. The network is not performing accurately because the optimization is too slow.
#
# 540/540 - 6s - loss: 27.2615 - accuracy: 0.0830 - val_loss: 27.4945 - val_accuracy: 0.0893
#
# 1/1 [==============================] - 1s 713ms/step - loss: 27.2504 - accuracy: 0.0755

# %% [markdown]
# ### 9. Adjust the learning rate. Try a value of 0.02. Does it make a difference?
#
#
# Testing with SGD, it got worst:
#
# Epoch 8/8
# 540/540 - 6s - loss: 27.2789 - accuracy: 0.0579 - val_loss: 27.4945 - val_accuracy: 0.0578
#
# 1/1 [==============================] - 1s 716ms/step - loss: 27.2504 - accuracy: 0.0597

# %% [markdown]
# ### 10. Combine all the methods above and try to reach a validation accuracy of 98.5+
# percent.

# %% [markdown]
# CNN experiment 1: val_accuracy: 0.9823 testing_acc: 0.984
#
# CNN experiment 2: val_accuracy: 0.9915 testing_acc: 0.9917
#
# CNN experiment 3: val_accuracy: 0.9917 testing_acc: 0.9922
